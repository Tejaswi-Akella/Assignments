# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df=pd.read_csv("SalaryData_Train.csv")
test_df=pd.read_csv("SalaryData_Test.csv")
train_df
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
import seaborn as sns

sns.countplot(data=train_df,hue='Salary',x='workclass')
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
sns.countplot(data=train_df,x='occupation',hue='workclass')
# Out:
# <AxesSubplot:xlabel='occupation', ylabel='count'>

# %%
sns.countplot(data=train_df,x='Salary')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
test_df
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sns.countplot(data=test_df,y='occupation')
# Out:
# <AxesSubplot:xlabel='count', ylabel='occupation'>

# %%
sns.countplot(data=test_df,x='Salary',hue='race')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
train_df.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

train_df['workclass'] = labelencoder.fit_transform(train_df['workclass'])
train_df['education'] = labelencoder.fit_transform(train_df['education'])
train_df['occupation'] = labelencoder.fit_transform(train_df['occupation'])
train_df['race'] = labelencoder.fit_transform(train_df['race'])
train_df['sex'] = labelencoder.fit_transform(train_df['sex'])
train_df['native'] = labelencoder.fit_transform(train_df['native'])
train_df['Salary'] = labelencoder.fit_transform(train_df['Salary'])
train_df['maritalstatus'] = labelencoder.fit_transform(train_df['maritalstatus'])
train_df['relationship'] = labelencoder.fit_transform(train_df['relationship'])
train_df
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
test_df['workclass'] = labelencoder.fit_transform(test_df['workclass'])
test_df['education'] = labelencoder.fit_transform(test_df['education'])
test_df['occupation'] = labelencoder.fit_transform(test_df['occupation'])
test_df['race'] = labelencoder.fit_transform(test_df['race'])
test_df['sex'] = labelencoder.fit_transform(test_df['sex'])
test_df['native'] = labelencoder.fit_transform(test_df['native'])
test_df['Salary'] = labelencoder.fit_transform(test_df['Salary'])
test_df['relationship'] = labelencoder.fit_transform(test_df['relationship'])
test_df['maritalstatus'] = labelencoder.fit_transform(test_df['maritalstatus'])

test_df
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
X_train = train_df.iloc[:,0:11]
X_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss
# ...

# %%
y_train = train_df['Salary']
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 30161, dtype: int32

# %%
X_test = test_df.iloc[:,0:11]
X_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss
# ...

# %%
y_test = test_df['Salary']
y_test
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15055    0
# 15056    0
# 15057    0
# 15058    0
# 15059    1
# Name: Salary, Length: 15060, dtype: int32

# %%
from sklearn import svm
classifier = svm.SVC(kernel='linear',gamma='auto',C=3)
model = classifier.fit(X_train,y_train)

# %%
y_predict = model.predict(X_test)

from sklearn.metrics import classification_report
classification_report(y_test,y_predict)
